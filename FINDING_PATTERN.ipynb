# %% [markdown]
# # IMPORTING PACKAGES

# %%
import numpy as np
import pandas as pd
import seaborn as sns
import warnings
from sklearn.preprocessing import LabelEncoder
import datetime
import matplotlib.pyplot as plt

pd.set_option('display.max_columns', 999)
warnings.filterwarnings("ignore")
warnings.warn('my warning')
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\statsmodels\tools\_testing.py:19: FutureWarning: pandas.util.testing is deprecated. Use the functions in the public API at pandas.testing instead.
#   import pandas.util.testing as tm

# %% [markdown]
# # READING THE FILE AND CONVERTING IT TO CSV

# %%
data=pd.read_excel(r'Order Analysis.xlsx')

# %%
data=data.to_csv(r'OrderAnalysis.csv', index = None, header=True)

# %%
data=pd.read_csv("OrderAnalysis.csv", parse_dates=["Order Created At"])

# %%
main=pd.read_csv('OrderAnalysis.csv')

# %%
#type(df.'Order Created At'[0])
main.head()
# Out:
#       Order Created At   Total  Total Items Shipping Address City  \
# 0  2020-11-16 16:22:43  1864.8            6                 Kochi
# 1  2020-11-16 15:18:07  1545.6            5            Aurangabad
# 2  2020-11-16 13:38:37  1008.0            3              Tirupati
# 3  2020-11-16 13:34:28   756.8            2            Sitarganj
# 4  2020-11-16 13:27:52   600.0            2       Kolkata-700070.
#
#   Shipping Address State Shipping Address Postcode  \
# 0                     KL                    682028
# 1                     MH                    431001
# 2                     AP                    517501
# 3                     UK                    262405
# 4                     WB                    700070
#
#              Shipping Method Title  \
# 0                              NaN
# 1  Cash on delivery (COD) Shipping
# 2  Cash on delivery (COD) Shipping
# 3  Cash on delivery (COD) Shipping
# 4  Cash on delivery (COD) Shipping
#
# ...

# %%
main['Line Items'].nunique()
# Out:
# 27256

# %%
main.count()
# Out:
# Order Created At             32138
# Total                        31993
# Total Items                  32138
# Shipping Address City        32130
# Shipping Address State       32017
# Shipping Address Postcode    32127
# Shipping Method Title        31282
# Referring Site               17244
# Line Items                   32138
# Coupon Codes                  8663
# Coupon Amounts                8663
# dtype: int64

# %% [markdown]
# # MAKING DATETIME COLUMN TO INDEX

# %%
main_pattern=main[['Order Created At','Total']]

# %%
main_pattern.head(1)
# Out:
#       Order Created At   Total
# 0  2020-11-16 16:22:43  1864.8

# %%
main_pattern
# Out:
#           Order Created At   Total
# 0      2020-11-16 16:22:43  1864.8
# 1      2020-11-16 15:18:07  1545.6
# 2      2020-11-16 13:38:37  1008.0
# 3      2020-11-16 13:34:28   756.8
# 4      2020-11-16 13:27:52   600.0
# ...                    ...     ...
# 32133  2015-05-18 21:50:16  1007.0
# 32134  2015-05-16 19:14:17  1007.0
# 32135  2015-05-14 15:51:38  1007.0
# 32136  2015-05-14 11:59:17  1007.0
# 32137  2015-05-06 19:28:59  1008.0
#
# [32138 rows x 2 columns]

# %%
type(main_pattern['Order Created At'][0])
# Out:
# str

# %%
df=pd.read_csv("OrderAnalysis.csv", parse_dates=["Order Created At"], index_col=['Order Created At'])

# %% [markdown]
# # SEPERATING THE DATA FOR EVERY MONTH

# %%
df2015=df['2016-01-01':'2015-05-04']
dec2017=df2017dec.Total.sum()
nov2017=df2017nov.Total.sum()
oct2017=df2017oct.Total.sum()
sept2017=df2017sept.Total.sum()
sept2017=df2017sept.Total.sum()
aug2017=df2017aug.Total.sum()
july2017=df2017july.Total.sum()
jun2017=df2017jun.Total.sum()
may2017=df2017may.Total.sum()
apr2017=df2017apr.Total.sum()
mar2017=df2017mar.Total.sum()
feb2017=df2017feb.Total.sum()
jan2017=df2017jan.Total.sum()

dec2016=df2016dec.Total.sum()
nov2016=df2016nov.Total.sum()
oct2016=df2016oct.Total.sum()
sept2016=df2016sept.Total.sum()
sept2016=df2016sept.Total.sum()
aug2016=df2016aug.Total.sum()
july2016=df2016july.Total.sum()
jun2016=df2016jun.Total.sum()
may2016=df2016may.Total.sum()
apr2016=df2016apr.Total.sum()
mar2016=df2016mar.Total.sum()
feb2016=df2016feb.Total.sum()
jan2016=df2016jan.Total.sum()

dec2015=df2015dec.Total.sum()
nov2015=df2015nov.Total.sum()
oct2015=df2015oct.Total.sum()
sept2015=df2015sept.Total.sum()
sept2015=df2015sept.Total.sum()
aug2015=df2015aug.Total.sum()
july2015=df2015july.Total.sum()
jun2015=df2015jun.Total.sum()
may2015=df2015may.Total.sum()
apr2015=df2015apr.Total.sum()
mar2015=df2015mar.Total.sum()
feb2015=df2015feb.Total.sum()
jan2015=df2015jan.Total.sum()

# %% [markdown]
# # LOOKING AT EVERY MONTH OF 2019 FOR SALES

# %%
df2019jan['Total'].plot(color='teal', figsize=(16,4), title="Pattern Of Buying in month of Jan 2019")

# %%
df2019feb['Total'].plot(color='teal', figsize=(16,4), title="Pattern Of Buying in month of Feb 2019")

# %%
df2019mar['Total'].plot(color='teal', figsize=(16,4), title="Pattern Of Buying in month of Mar 2019")

# %%
df2019apr['Total'].plot(color='teal', figsize=(16,4), title="Pattern Of Buying in month of Apr 2019")

# %%
df2019may['Total'].plot(color='teal', figsize=(16,4), title="Pattern Of Buying in month of May 2019")

# %%
df2019jun['Total'].plot(color='teal', figsize=(16,4), title="Pattern Of Buying in month of Jun 2019")

# %%
df2019july['Total'].plot(color='teal', figsize=(16,4), title="Pattern Of Buying in month of July 2019")

# %%
df2019aug['Total'].plot(color='teal', figsize=(16,4), title="Pattern Of Buying in month of Aug 2019")

# %%
df2019sept['Total'].plot(color='teal', figsize=(16,4), title="Pattern Of Buying in month of Sept 2019")

# %%
df2019oct['Total'].plot(color='teal', figsize=(16,4), title="Pattern Of Buying in month of Oct 2019")

# %%
df2019nov['Total'].plot(color='teal', figsize=(16,4), title="Pattern Of Buying in month of Nov 2019")

# %%
df2019dec['Total'].plot(color='teal', figsize=(16,4), title="Pattern Of Buying in month of Dec 2019")
